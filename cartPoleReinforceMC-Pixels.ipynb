# %%
import gym 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import scipy.ndimage

# %%
env = gym.make("CartPole-v0")
# Out:
# [2017-09-17 16:37:02,977] Making new env: CartPole-v0

# %%
# Environment Parameters
n_inputs = [90,80] 
n_actions = env.action_space.n
states, actions, rewards = [], [], []
episode_num = 1
n_episodes = 10000
G = 0
average, avg_loss = [], []
render = False

# Hyper Parameters
learning_rate = 1e-7
gamma = .99
save_path='models/cartPole.ckpt'

# Conv Layers
convs = [64, 128]
kerns = [8, 4]
strides = [4, 2]
pads = 'VALID'


# TF Placeholders
X = tf.placeholder(tf.float32, shape=(None, 90, 80, 1), name="X")
Y = tf.placeholder(dtype=tf.float32, shape=[None, n_actions],name="Y")
eps_rewards = tf.placeholder(dtype=tf.float32, shape=[None,1], name="Episode_Rewards")

# %%
def resize(image):
    x = np.around(np.mean(image,-1))
    #x = (x-128)/128 - 1
    x = scipy.misc.imresize(x, [90,80],interp='bicubic')
    return(x)

# %%
# CONVOLUTION 1 - 1
with tf.name_scope('conv1_1'):
    filter1 = tf.Variable(tf.truncated_normal([8, 8, 1, 64], dtype=tf.float32,
                            stddev=1/np.sqrt(90*80)), name='weights1')
    stride = [1,4,4,1]
    conv = tf.nn.conv2d(X, filter1, stride, padding='VALID')
    biases = tf.Variable(tf.constant(0.0, shape=[convs[0]], dtype=tf.float32),
                         trainable=True, name='biases1')
    out = tf.nn.bias_add(conv, biases)
    conv1 = tf.nn.relu(out)
    
    
# CONVOLUTION 1 - 2
with tf.name_scope('conv1_2'):
    filter2 = tf.Variable(tf.truncated_normal([kerns[1], kerns[1], convs[0], convs[1]], dtype=tf.float32,
                                                stddev=1/np.sqrt(int(np.prod(conv1.get_shape()[1:])))), name='weights2')
    stride = [1,strides[1],strides[0],1]
    conv = tf.nn.conv2d(conv1, filter2, stride, padding=pads)
    biases = tf.Variable(tf.constant(0.0, shape=[convs[1]], dtype=tf.float32),
                         trainable=True, name='biases2')
    out = tf.nn.bias_add(conv, biases)
    conv2 = tf.nn.relu(out)
    

#FULLY CONNECTED 1
with tf.name_scope('fc1') as scope:
    shape = int(np.prod(conv2.get_shape()[1:]))
    fc1w = tf.Variable(tf.truncated_normal([shape, fc], dtype=tf.float32, stddev=1/np.sqrt(shape)), name='weights3')
    fc1b = tf.Variable(tf.constant(1.0, shape=[fc], dtype=tf.float32),
                       trainable=True, name='biases3')
    flat = tf.reshape(conv2, [-1, shape])
    out = tf.nn.bias_add(tf.matmul(flat, fc1w), fc1b)
    fc1 = tf.nn.relu(out)
    

#FULLY CONNECTED 2 & SOFTMAX OUTPUT
with tf.name_scope('softmax') as scope:
    fc2w = tf.Variable(tf.truncated_normal([fc, n_actions], dtype=tf.float32,
                                           stddev=1e-1), name='weights4')
    fc2b = tf.Variable(tf.constant(1.0, shape=[n_actions], dtype=tf.float32),
                       trainable=True, name='biases4')
    Ylogits = tf.nn.bias_add(tf.matmul(fc1, fc2w), fc2b)
    output = tf.nn.softmax(Ylogits)

# %%
# Apply discount to episode rewards & normalize
def discount_rewards(rewards, gamma):
    dis_r = np.zeros_like(rewards)
    G = 0
    for i in reversed(range(0, len(rewards))):
        G = G * gamma + rewards[i]
        dis_r[i] = G
        
    # Normalize rewards add 1e-3 to std incase it's 0
    dis_r = (dis_r - np.mean(dis_r)) / (np.std(dis_r)+1e-5)
    return dis_r

# %%
# Define loss
loss = tf.nn.l2_loss(Y - output)
loss_mean = tf.reduce_mean(loss)
optimizer = tf.train.AdamOptimizer(learning_rate)
grads = optimizer.compute_gradients(loss, var_list=tf.trainable_variables(), grad_loss=eps_rewards)
train = optimizer.apply_gradients(grads)

# %%
# Define Session and initialize variables
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
state = env.reset()
state = resize(env.render(mode='rgb_array'))

for i in range(n_episodes):
    
    while True:
        
        if render:
            env.render()
        # Get action probability from network
        aprob = sess.run([output], feed_dict={X:state.reshape(1, 90, 80, 1)})
        action = np.random.choice(n_actions, p=aprob[0][0])
        oneHot = np.zeros(n_actions)
        oneHot[action] = 1
    
        # Perform action & store results
        state2, reward, done, info = env.step(action)
        G += reward
    
        # Record history
        states.append(state)
        actions.append(oneHot)
        rewards.append(reward)
    
        # Update current state
        state = resize(env.render(mode='rgb_array'))
    
        if done:
            
            average.append(G)
            rewards = discount_rewards(rewards,gamma)
            
            # Feed history into network
            feed = {X: np.dstack(states).reshape(len(states),90,80,1), eps_rewards: np.vstack(rewards), Y: np.vstack(actions)}
            _, losses = sess.run([train, loss_mean], feed_dict=feed)
            avg_loss.append(losses)
            
            if episode_num % 10 == 0:
                print('Episode: {}   G: {}  Average: {:4.3f}  Avg. Loss: {:4.3f}'.format(episode_num, G, np.mean(average), np.mean(avg_loss)))
            
            states, actions, rewards = [], [], []
            G = 0
            state = env.reset()
            state = resize(env.render(mode='rgb_array'))
            episode_num += 1
            break
                
    if sum(average[episode_num-100:episode_num])/100 >= 195:
        print('Solved in {} Episodes'.format(episode_num))
        break
# Out:
# Episode: 10   G: 23.0  Average: 18.300  Avg. Loss: 4.088
# Episode: 20   G: 14.0  Average: 18.750  Avg. Loss: 4.313
# Episode: 30   G: 11.0  Average: 17.167  Avg. Loss: 3.821
# Episode: 40   G: 12.0  Average: 17.725  Avg. Loss: 3.938
# Episode: 50   G: 49.0  Average: 19.260  Avg. Loss: 4.400
# Episode: 60   G: 20.0  Average: 19.117  Avg. Loss: 4.442
# Episode: 70   G: 14.0  Average: 20.371  Avg. Loss: 4.772
# Episode: 80   G: 10.0  Average: 20.425  Avg. Loss: 4.831
# Episode: 90   G: 28.0  Average: 20.833  Avg. Loss: 4.961
# Episode: 100   G: 14.0  Average: 20.590  Avg. Loss: 4.946
# Episode: 110   G: 14.0  Average: 21.036  Avg. Loss: 5.108
# Episode: 120   G: 25.0  Average: 22.200  Avg. Loss: 5.419
# Episode: 130   G: 14.0  Average: 22.738  Avg. Loss: 5.552
# Episode: 140   G: 12.0  Average: 22.586  Avg. Loss: 5.527
# Episode: 150   G: 21.0  Average: 22.573  Avg. Loss: 5.538
# Episode: 160   G: 22.0  Average: 22.400  Avg. Loss: 5.510
# Episode: 170   G: 20.0  Average: 22.071  Avg. Loss: 5.443
# Episode: 180   G: 49.0  Average: 22.556  Avg. Loss: 5.577
# Episode: 190   G: 17.0  Average: 22.642  Avg. Loss: 5.607
# Episode: 200   G: 10.0  Average: 22.750  Avg. Loss: 5.653
# Episode: 210   G: 31.0  Average: 23.062  Avg. Loss: 5.740
# Episode: 220   G: 16.0  Average: 23.123  Avg. Loss: 5.761
# Episode: 230   G: 19.0  Average: 23.017  Avg. Loss: 5.745
# Episode: 240   G: 18.0  Average: 22.892  Avg. Loss: 5.715
# Episode: 250   G: 27.0  Average: 22.836  Avg. Loss: 5.708
# Episode: 260   G: 11.0  Average: 22.762  Avg. Loss: 5.696
# Episode: 270   G: 30.0  Average: 22.685  Avg. Loss: 5.683
# Episode: 280   G: 17.0  Average: 22.593  Avg. Loss: 5.658
# Episode: 290   G: 25.0  Average: 22.545  Avg. Loss: 5.650
# Episode: 300   G: 35.0  Average: 22.477  Avg. Loss: 5.636
# Episode: 310   G: 21.0  Average: 22.545  Avg. Loss: 5.656
# Episode: 320   G: 54.0  Average: 22.628  Avg. Loss: 5.679
# Episode: 330   G: 23.0  Average: 22.615  Avg. Loss: 5.680
# Episode: 340   G: 15.0  Average: 22.462  Avg. Loss: 5.646
# Episode: 350   G: 27.0  Average: 22.434  Avg. Loss: 5.641
# Episode: 360   G: 15.0  Average: 22.528  Avg. Loss: 5.667
# Episode: 370   G: 26.0  Average: 22.524  Avg. Loss: 5.665
# Episode: 380   G: 10.0  Average: 22.526  Avg. Loss: 5.666
# Episode: 390   G: 16.0  Average: 22.444  Avg. Loss: 5.644
# Episode: 400   G: 27.0  Average: 22.340  Avg. Loss: 5.620
# Episode: 410   G: 19.0  Average: 22.541  Avg. Loss: 5.668
# Episode: 420   G: 18.0  Average: 22.731  Avg. Loss: 5.716
# Episode: 430   G: 10.0  Average: 22.742  Avg. Loss: 5.720
# Episode: 440   G: 63.0  Average: 22.848  Avg. Loss: 5.745
# Episode: 450   G: 16.0  Average: 22.773  Avg. Loss: 5.731
# Episode: 460   G: 18.0  Average: 22.667  Avg. Loss: 5.705
# Episode: 470   G: 17.0  Average: 22.770  Avg. Loss: 5.731
# Episode: 480   G: 14.0  Average: 22.704  Avg. Loss: 5.715
# Episode: 490   G: 27.0  Average: 22.629  Avg. Loss: 5.696
# Episode: 500   G: 11.0  Average: 22.462  Avg. Loss: 5.653
# Episode: 510   G: 11.0  Average: 22.357  Avg. Loss: 5.626
# Episode: 520   G: 26.0  Average: 22.250  Avg. Loss: 5.601
# Episode: 530   G: 21.0  Average: 22.192  Avg. Loss: 5.587
# Episode: 540   G: 11.0  Average: 22.061  Avg. Loss: 5.552
# Episode: 550   G: 13.0  Average: 22.138  Avg. Loss: 5.572
# Episode: 560   G: 11.0  Average: 22.205  Avg. Loss: 5.589
# Episode: 570   G: 41.0  Average: 22.168  Avg. Loss: 5.580
# Episode: 580   G: 12.0  Average: 22.212  Avg. Loss: 5.592
# Episode: 590   G: 41.0  Average: 22.232  Avg. Loss: 5.598
# Episode: 600   G: 25.0  Average: 22.330  Avg. Loss: 5.622
# Episode: 610   G: 39.0  Average: 22.457  Avg. Loss: 5.654
# Episode: 620   G: 20.0  Average: 22.552  Avg. Loss: 5.674
# Episode: 630   G: 34.0  Average: 22.563  Avg. Loss: 5.677
# Episode: 640   G: 41.0  Average: 22.639  Avg. Loss: 5.697
# Episode: 650   G: 35.0  Average: 22.632  Avg. Loss: 5.695
# Episode: 660   G: 24.0  Average: 22.576  Avg. Loss: 5.680
# Episode: 670   G: 14.0  Average: 22.554  Avg. Loss: 5.677
# Episode: 680   G: 21.0  Average: 22.501  Avg. Loss: 5.663
# Episode: 690   G: 17.0  Average: 22.496  Avg. Loss: 5.660
# Episode: 700   G: 38.0  Average: 22.497  Avg. Loss: 5.660
# Episode: 710   G: 32.0  Average: 22.537  Avg. Loss: 5.667
# Episode: 720   G: 33.0  Average: 22.649  Avg. Loss: 5.695
# Episode: 730   G: 34.0  Average: 22.673  Avg. Loss: 5.702
# Episode: 740   G: 22.0  Average: 22.611  Avg. Loss: 5.687
# Episode: 750   G: 33.0  Average: 22.569  Avg. Loss: 5.677
# Episode: 760   G: 19.0  Average: 22.509  Avg. Loss: 5.663
# Episode: 770   G: 25.0  Average: 22.458  Avg. Loss: 5.650
# Episode: 780   G: 17.0  Average: 22.413  Avg. Loss: 5.639
# Episode: 790   G: 13.0  Average: 22.365  Avg. Loss: 5.628
# Episode: 800   G: 16.0  Average: 22.399  Avg. Loss: 5.637
# Episode: 810   G: 57.0  Average: 22.374  Avg. Loss: 5.630
# Episode: 820   G: 20.0  Average: 22.366  Avg. Loss: 5.629
# Episode: 830   G: 18.0  Average: 22.404  Avg. Loss: 5.639
# Episode: 840   G: 30.0  Average: 22.392  Avg. Loss: 5.636
# Episode: 850   G: 20.0  Average: 22.333  Avg. Loss: 5.620
# Episode: 860   G: 41.0  Average: 22.303  Avg. Loss: 5.615
# Episode: 870   G: 21.0  Average: 22.346  Avg. Loss: 5.625
# Episode: 880   G: 16.0  Average: 22.305  Avg. Loss: 5.615
# Episode: 890   G: 15.0  Average: 22.283  Avg. Loss: 5.610
# Episode: 900   G: 27.0  Average: 22.291  Avg. Loss: 5.612
# Episode: 910   G: 13.0  Average: 22.226  Avg. Loss: 5.597
# Episode: 920   G: 21.0  Average: 22.263  Avg. Loss: 5.606
# Episode: 930   G: 23.0  Average: 22.288  Avg. Loss: 5.614
# Episode: 940   G: 25.0  Average: 22.296  Avg. Loss: 5.617
# Episode: 950   G: 12.0  Average: 22.240  Avg. Loss: 5.603
# Episode: 960   G: 17.0  Average: 22.244  Avg. Loss: 5.604
# Episode: 970   G: 19.0  Average: 22.263  Avg. Loss: 5.609
# Episode: 980   G: 14.0  Average: 22.247  Avg. Loss: 5.606
# Episode: 990   G: 19.0  Average: 22.222  Avg. Loss: 5.600
# Episode: 1000   G: 12.0  Average: 22.207  Avg. Loss: 5.597
# Episode: 1010   G: 12.0  Average: 22.198  Avg. Loss: 5.594
# Episode: 1020   G: 36.0  Average: 22.148  Avg. Loss: 5.581
# Episode: 1030   G: 12.0  Average: 22.133  Avg. Loss: 5.579
# Episode: 1040   G: 41.0  Average: 22.166  Avg. Loss: 5.588
# Episode: 1050   G: 22.0  Average: 22.166  Avg. Loss: 5.589
# Episode: 1060   G: 22.0  Average: 22.201  Avg. Loss: 5.599
# Episode: 1070   G: 18.0  Average: 22.188  Avg. Loss: 5.596
# Episode: 1080   G: 11.0  Average: 22.141  Avg. Loss: 5.583
# Episode: 1090   G: 13.0  Average: 22.145  Avg. Loss: 5.586
# Episode: 1100   G: 9.0  Average: 22.111  Avg. Loss: 5.580
# Episode: 1110   G: 14.0  Average: 22.078  Avg. Loss: 5.570
# Episode: 1120   G: 12.0  Average: 22.087  Avg. Loss: 5.572
# Episode: 1130   G: 12.0  Average: 22.072  Avg. Loss: 5.566
# Episode: 1140   G: 14.0  Average: 22.077  Avg. Loss: 5.567
# Episode: 1150   G: 17.0  Average: 22.086  Avg. Loss: 5.569
# Episode: 1160   G: 30.0  Average: 22.099  Avg. Loss: 5.574
# Episode: 1170   G: 16.0  Average: 22.118  Avg. Loss: 5.576
# Episode: 1180   G: 17.0  Average: 22.209  Avg. Loss: 5.598
# Episode: 1190   G: 24.0  Average: 22.217  Avg. Loss: 5.601
# Episode: 1200   G: 11.0  Average: 22.207  Avg. Loss: 5.599
# Episode: 1210   G: 10.0  Average: 22.208  Avg. Loss: 5.599
# Episode: 1220   G: 42.0  Average: 22.252  Avg. Loss: 5.611
# Episode: 1230   G: 25.0  Average: 22.254  Avg. Loss: 5.612
# Episode: 1240   G: 9.0  Average: 22.209  Avg. Loss: 5.600
# Episode: 1250   G: 26.0  Average: 22.158  Avg. Loss: 5.587
# Episode: 1260   G: 23.0  Average: 22.132  Avg. Loss: 5.581
# Episode: 1270   G: 27.0  Average: 22.143  Avg. Loss: 5.585
# Episode: 1280   G: 46.0  Average: 22.241  Avg. Loss: 5.609
# Episode: 1290   G: 15.0  Average: 22.211  Avg. Loss: 5.601
# Episode: 1300   G: 50.0  Average: 22.222  Avg. Loss: 5.604
# Episode: 1310   G: 16.0  Average: 22.198  Avg. Loss: 5.599
# Episode: 1320   G: 12.0  Average: 22.223  Avg. Loss: 5.606
# Episode: 1330   G: 26.0  Average: 22.211  Avg. Loss: 5.603
# Episode: 1340   G: 15.0  Average: 22.213  Avg. Loss: 5.604
# Episode: 1350   G: 15.0  Average: 22.246  Avg. Loss: 5.613
# Episode: 1360   G: 60.0  Average: 22.316  Avg. Loss: 5.629
# Episode: 1370   G: 19.0  Average: 22.345  Avg. Loss: 5.637
# Episode: 1380   G: 17.0  Average: 22.312  Avg. Loss: 5.628
# Episode: 1390   G: 14.0  Average: 22.292  Avg. Loss: 5.623
# Episode: 1400   G: 36.0  Average: 22.334  Avg. Loss: 5.633
# Episode: 1410   G: 39.0  Average: 22.370  Avg. Loss: 5.642
# Episode: 1420   G: 21.0  Average: 22.341  Avg. Loss: 5.634
# Episode: 1430   G: 26.0  Average: 22.323  Avg. Loss: 5.629
# Episode: 1440   G: 9.0  Average: 22.310  Avg. Loss: 5.627
# Episode: 1450   G: 15.0  Average: 22.287  Avg. Loss: 5.621
# Episode: 1460   G: 19.0  Average: 22.338  Avg. Loss: 5.633
# Episode: 1470   G: 18.0  Average: 22.333  Avg. Loss: 5.631
# Episode: 1480   G: 28.0  Average: 22.316  Avg. Loss: 5.627
# Episode: 1490   G: 29.0  Average: 22.333  Avg. Loss: 5.631
# Episode: 1500   G: 11.0  Average: 22.288  Avg. Loss: 5.620
# Episode: 1510   G: 17.0  Average: 22.266  Avg. Loss: 5.615
# Episode: 1520   G: 17.0  Average: 22.242  Avg. Loss: 5.608
# Episode: 1530   G: 13.0  Average: 22.250  Avg. Loss: 5.610
# Episode: 1540   G: 18.0  Average: 22.240  Avg. Loss: 5.608
# Episode: 1550   G: 34.0  Average: 22.235  Avg. Loss: 5.606
# Episode: 1560   G: 15.0  Average: 22.227  Avg. Loss: 5.603
# Episode: 1570   G: 26.0  Average: 22.218  Avg. Loss: 5.602
# Episode: 1580   G: 31.0  Average: 22.228  Avg. Loss: 5.604
# Episode: 1590   G: 18.0  Average: 22.269  Avg. Loss: 5.614
# Episode: 1600   G: 34.0  Average: 22.273  Avg. Loss: 5.616
# Episode: 1610   G: 26.0  Average: 22.293  Avg. Loss: 5.621
# Episode: 1620   G: 24.0  Average: 22.298  Avg. Loss: 5.622
# Episode: 1630   G: 21.0  Average: 22.323  Avg. Loss: 5.629
# Episode: 1640   G: 9.0  Average: 22.337  Avg. Loss: 5.632
# Episode: 1650   G: 14.0  Average: 22.358  Avg. Loss: 5.638
# Episode: 1660   G: 9.0  Average: 22.322  Avg. Loss: 5.629
# Episode: 1670   G: 51.0  Average: 22.316  Avg. Loss: 5.628
# Episode: 1680   G: 28.0  Average: 22.333  Avg. Loss: 5.632
# Episode: 1690   G: 13.0  Average: 22.327  Avg. Loss: 5.631
# Episode: 1700   G: 54.0  Average: 22.343  Avg. Loss: 5.635
# Episode: 1710   G: 37.0  Average: 22.330  Avg. Loss: 5.632
# Episode: 1720   G: 14.0  Average: 22.309  Avg. Loss: 5.627
# Episode: 1730   G: 35.0  Average: 22.313  Avg. Loss: 5.628
# Episode: 1740   G: 13.0  Average: 22.318  Avg. Loss: 5.629
# Episode: 1750   G: 32.0  Average: 22.309  Avg. Loss: 5.628
# Episode: 1760   G: 12.0  Average: 22.349  Avg. Loss: 5.638
# Episode: 1770   G: 47.0  Average: 22.349  Avg. Loss: 5.639
# Episode: 1780   G: 11.0  Average: 22.337  Avg. Loss: 5.636
# Episode: 1790   G: 24.0  Average: 22.380  Avg. Loss: 5.647
# Episode: 1800   G: 9.0  Average: 22.391  Avg. Loss: 5.649
# Episode: 1810   G: 10.0  Average: 22.401  Avg. Loss: 5.651
# Episode: 1820   G: 27.0  Average: 22.399  Avg. Loss: 5.651
# Episode: 1830   G: 23.0  Average: 22.379  Avg. Loss: 5.646
# Episode: 1840   G: 25.0  Average: 22.394  Avg. Loss: 5.650
# Episode: 1850   G: 21.0  Average: 22.392  Avg. Loss: 5.650
# Episode: 1860   G: 30.0  Average: 22.383  Avg. Loss: 5.648
# Episode: 1870   G: 11.0  Average: 22.390  Avg. Loss: 5.650
# Episode: 1880   G: 40.0  Average: 22.377  Avg. Loss: 5.646
# Episode: 1890   G: 25.0  Average: 22.405  Avg. Loss: 5.654
# Episode: 1900   G: 19.0  Average: 22.378  Avg. Loss: 5.648
# Episode: 1910   G: 21.0  Average: 22.360  Avg. Loss: 5.643
# Episode: 1920   G: 24.0  Average: 22.343  Avg. Loss: 5.639
# Episode: 1930   G: 14.0  Average: 22.325  Avg. Loss: 5.635
# Episode: 1940   G: 25.0  Average: 22.329  Avg. Loss: 5.636
# Episode: 1950   G: 36.0  Average: 22.329  Avg. Loss: 5.636
# Episode: 1960   G: 20.0  Average: 22.335  Avg. Loss: 5.637
# Episode: 1970   G: 15.0  Average: 22.350  Avg. Loss: 5.641
# Episode: 1980   G: 13.0  Average: 22.359  Avg. Loss: 5.644
# Episode: 1990   G: 23.0  Average: 22.363  Avg. Loss: 5.645
# Episode: 2000   G: 17.0  Average: 22.390  Avg. Loss: 5.651
# Episode: 2010   G: 13.0  Average: 22.364  Avg. Loss: 5.645
# Episode: 2020   G: 15.0  Average: 22.374  Avg. Loss: 5.648
# Episode: 2030   G: 16.0  Average: 22.373  Avg. Loss: 5.648
# Episode: 2040   G: 20.0  Average: 22.398  Avg. Loss: 5.654
# Episode: 2050   G: 13.0  Average: 22.407  Avg. Loss: 5.658
# Episode: 2060   G: 15.0  Average: 22.381  Avg. Loss: 5.652
# Episode: 2070   G: 26.0  Average: 22.408  Avg. Loss: 5.659
# Episode: 2080   G: 26.0  Average: 22.427  Avg. Loss: 5.664
# Episode: 2090   G: 27.0  Average: 22.437  Avg. Loss: 5.666
# Episode: 2100   G: 12.0  Average: 22.451  Avg. Loss: 5.669
# Episode: 2110   G: 28.0  Average: 22.453  Avg. Loss: 5.669
# Episode: 2120   G: 14.0  Average: 22.460  Avg. Loss: 5.672
# Episode: 2130   G: 19.0  Average: 22.431  Avg. Loss: 5.665
# Episode: 2140   G: 21.0  Average: 22.421  Avg. Loss: 5.663
# Episode: 2150   G: 23.0  Average: 22.456  Avg. Loss: 5.671
# Episode: 2160   G: 35.0  Average: 22.473  Avg. Loss: 5.675
# Episode: 2170   G: 17.0  Average: 22.461  Avg. Loss: 5.672
# Episode: 2180   G: 10.0  Average: 22.437  Avg. Loss: 5.667
# Episode: 2190   G: 14.0  Average: 22.406  Avg. Loss: 5.659
# Episode: 2200   G: 11.0  Average: 22.415  Avg. Loss: 5.661
# Episode: 2210   G: 12.0  Average: 22.397  Avg. Loss: 5.657
# Episode: 2220   G: 12.0  Average: 22.399  Avg. Loss: 5.658
# Episode: 2230   G: 20.0  Average: 22.378  Avg. Loss: 5.652
# Episode: 2240   G: 50.0  Average: 22.370  Avg. Loss: 5.649
# Episode: 2250   G: 29.0  Average: 22.363  Avg. Loss: 5.648
# Episode: 2260   G: 19.0  Average: 22.358  Avg. Loss: 5.647
# Episode: 2270   G: 26.0  Average: 22.382  Avg. Loss: 5.653
# Episode: 2280   G: 16.0  Average: 22.378  Avg. Loss: 5.651
# Episode: 2290   G: 14.0  Average: 22.348  Avg. Loss: 5.643
# Episode: 2300   G: 12.0  Average: 22.358  Avg. Loss: 5.646
# Episode: 2310   G: 11.0  Average: 22.352  Avg. Loss: 5.644
# Episode: 2320   G: 34.0  Average: 22.394  Avg. Loss: 5.655
# Episode: 2330   G: 11.0  Average: 22.407  Avg. Loss: 5.658
# Episode: 2340   G: 10.0  Average: 22.386  Avg. Loss: 5.652
# Episode: 2350   G: 67.0  Average: 22.415  Avg. Loss: 5.659
# Episode: 2360   G: 17.0  Average: 22.385  Avg. Loss: 5.651
# Episode: 2370   G: 12.0  Average: 22.362  Avg. Loss: 5.645
# Episode: 2380   G: 16.0  Average: 22.358  Avg. Loss: 5.644
# Episode: 2390   G: 13.0  Average: 22.353  Avg. Loss: 5.643
# Episode: 2400   G: 14.0  Average: 22.348  Avg. Loss: 5.642
# Episode: 2410   G: 69.0  Average: 22.347  Avg. Loss: 5.642
# Episode: 2420   G: 12.0  Average: 22.347  Avg. Loss: 5.642
# Episode: 2430   G: 39.0  Average: 22.342  Avg. Loss: 5.640
# Episode: 2440   G: 9.0  Average: 22.319  Avg. Loss: 5.635
# Episode: 2450   G: 13.0  Average: 22.288  Avg. Loss: 5.627
# Episode: 2460   G: 12.0  Average: 22.296  Avg. Loss: 5.629
# Episode: 2470   G: 10.0  Average: 22.273  Avg. Loss: 5.624
# Episode: 2480   G: 49.0  Average: 22.298  Avg. Loss: 5.629
# Episode: 2490   G: 12.0  Average: 22.298  Avg. Loss: 5.629
# Episode: 2500   G: 34.0  Average: 22.293  Avg. Loss: 5.628

# %%
aprob = sess.run([output], feed_dict={X:state.reshape(1, 90, 80, 1)})

# %%
conv1
